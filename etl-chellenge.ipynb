# %%
from bs4 import BeautifulSoup
import requests 
import re
import pandas as pd
from sqlalchemy import create_engine

# %%
from config import postgrepass

# %% [markdown]
# ### About the project
#
# Being an ESL Student (English as Second Language) I think it is important to learn meaning of new words before you read article or book. It is really boring to read anythink if you need to translate every 3rd word in a sentence. There are a lot of apps around that show word translation by clicking on the word, but they show only one-two meaning and not always the right one. Like in any other languages, one english word can have multiple meaning depending of context. In this project I take article names and their content and provide the list of unique words that ESL student can learn before read news.
#
# #### Resources
#
# <ul>
#     <li>News:  https://www.nbcbayarea.com/news/local/</li>
#     <li>Word Category: https://www.englishclub.com/</li>
# </ul>

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# First of all I want to grab list of English pronouns, prepositions, articles and etc and put them to postgre. It help avoid grab the same lists next time.

# %% [markdown]
# ##### Set up connection to DB

# %%
# Create connection to DB
db_path = f'postgresql://postgres:{postgrepass}@localhost:5432/new_word_study'
engine = create_engine(db_path)
conn = engine.connect()

# %% [markdown]
# ##### Prepositions

# %%
# get preposition from web
prep_url = 'https://www.englishclub.com/grammar/prepositions-list.htm'
prep_response = requests.get(prep_url)

# %%
# parce responce with BeautifulSoap
prep_soup = BeautifulSoup(prep_response.text, 'html.parser')

# %%
# find desirable part of html that contain list of prepositions, modify it to lower case and upload to DB. 
prepositions_draft = prep_soup.find('main').find_all('li')
prepositions = []

for preposition in prepositions_draft:
    prepositions.append(preposition.text.lower())

prepositions_df = pd.DataFrame(prepositions, columns=['preposition'])
prepositions_df.to_sql('prepositions', conn, if_exists='append')

# %% [markdown]
# ##### Pronouns

# %%
# get pronouns from web
pronoun_url = 'https://7esl.com/pronouns-list/'
pronoun_resp = requests.get(pronoun_url)

# %%
# parce responce woth BeaitifulSoap
pronoun_soup = BeautifulSoup(pronoun_resp.text, 'html.parser')

# %%
# find desirable part of html that contain list of pronoun, modify it to lower case and upload to DB. 
pronoun_draft = pronoun_soup.find('div', class_='thecontent clearfix').find_all('li')
pronoun_draft = pronoun_draft[51:162]
pronouns = []

for word in pronoun_draft:
    pronouns.append(word.text.lower())
    
pronouns_df = pd.DataFrame(pronouns, columns=['pronoun'])
pronouns_df.to_sql('pronouns', conn, if_exists='append')

# %% [markdown]
# ##### Conjunctions

# %%
# get conjunctions from web
conjunction_url = 'https://englishstudyhere.com/conjunctions/100-common-conjunctions/'
conj_response = requests.get(conjunction_url)

# %%
# parse responce 
conj_soup = BeautifulSoup(conj_response.text, 'html.parser')

# %%
# find desirable part of html that contain list of conjunctions, modify it to lower case and upload to DB. 
conj_draft = conj_soup.find('div', class_='thecontent clearfix').find_all('li')

conjuctions = []

for conj in conj_draft:
    conjuctions.append(conj.text.lower())
    
conj_df = pd.DataFrame(conjuctions, columns=['conjunction'])
conj_df.to_sql('conjunctions', conn, if_exists='append')

# %% [markdown]
# ##### Different type of words

# %%
# Category for words

articles = ['a', 'an', 'the']
weekdays = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']
months = ["january", 'february', "march", "april", "may"
          , "june", "july", "august", "september", "october", "november", "december"]

# %% [markdown]
# ### Extract Articles
#
# I choose nbcbayarea.com as the one of the most popuar news resources. I grab article names and link on them and store it to DF because page with news updates very often and I want to provide list of words for article that I can read after learn new words.

# %%
# set url to a target page on nbcbayarea.com
url = "https://www.nbcbayarea.com/news/local/"

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Find articles 
art_content = soup.find_all('a', class_="story-card__title-link")

art_content
# Out:
# [<a class="story-card__title-link" href="https://www.nbcbayarea.com/coronavirus-2/bay-area-seniors-hoping-to-get-covid-19-vaccine-feel-discouraged-by-lack-of-availability/2445816/">
#  									Bay Area Seniors Hoping to Get COVID-19 Vaccine Feel ‘Discouraged' by Lack of Availability											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/investigations/report-energy-market-selloff-led-to-blackouts-in-record-heatwave/2445860/">
#  									Report: Energy Market Selloff Led to Blackouts in Record Heatwave											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/current-covid-19-vaccine-supply-not-enough-to-vaccinate-all-seniors-immediately/2445783/">
#  									Current COVID-19 Vaccine Supply Not Enough to Vaccinate All Seniors Immediately											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/san-francisco/sf-announces-over-62m-in-relief-funds-for-small-businesses-as-pandemic-endures/2444374/">
#  									SF Announces Over $62M in Relief Funds for Small Businesses as Pandemic Endures											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/bart-to-hire-20-trained-social-workers/2445364/">
#  									BART to Hire 20 Trained Social Workers											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/san-francisco/sf-city-leaders-remain-hopeful-as-new-covid-19-surge-post-christmas-becomes-evident/2444096/">
#  									SF City Leaders Remain Hopeful as New COVID-19 Surge Post-Christmas Becomes Evident											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/property-owners-take-a-hit-as-pandemic-induced-business-closures-continue/2445694/">
#  									Property Owners Take a Hit as Pandemic-Induced Business Closures Continue											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/south-bay/covid-19-cases-soar-at-santa-clara-county-jail/2445353/">
#  									COVID-19 Cases Soar at Santa Clara County Jail											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/south-bay/5-number-lotto-winner-in-san-jose/2445322/">
#  									5-Number Powerball Ticket Worth $2.7M Sold in San Jose											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/man-accused-in-ghost-ship-fire-that-killed-36-expected-to-plead-guilty/2445637/">
#  									Man Accused in Ghost Ship Fire That Killed 36 Expected to Plead Guilty											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/3-8-magnitude-earthquake-strikes-in-concord-area/2445592/">
#  									3.8 Magnitude Earthquake in Concord Felt Across Bay Area											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/race-for-a-vaccine/seniors-65-and-up-can-schedule-covid-19-vaccine-in-contra-costa-county/2445457/">
#  									Seniors 65 and Up Can Schedule COVID-19 Vaccine in Contra Costa County											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/peninsula/watermain-break-in-south-san-francisco-leads-to-extended-road-closure/2445410/">
#  									Water Main Break in South San Francisco Leads to Extended Road Closure											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/authorities-in-san-mateo-county-search-for-missing-14-year-old/2444975/">
#  									Authorities in San Mateo County Search for Missing 14-Year-Old											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/peninsula/san-mateo-countys-community-wellness-and-crisis-response-pilot-project-approved/2444514/">
#  									San Mateo County's Community Wellness and Crisis Response Pilot Project Approved											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/elephant-seals-take-over-beach-in-marin-county-force-closure/2445635/">
#  									Elephant Seals Take Over Beach in Marin County, Force Closure											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/bay-area-proud/santa-rosa-artist-honors-front-line-workers-with-free-portraits/2444917/">
#  									Santa Rosa Artist Honors Frontline Workers With Free Portraits											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/mass-covid-19-vaccination-site-opens-at-sonoma-county-fairgrounds/2445114/">
#  									Mass COVID-19 Vaccination Site Opens at Sonoma County Fairgrounds											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/california/california-mobilizes-national-guard-amid-concern-over-unrest/2445755/">
#  									California Mobilizes National Guard Amid Concern Over Unrest											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/entertainment/entertainment-news/disneyland-to-end-current-annual-passport-program-issue-refunds-due-to-pandemic/2445698/">
#  									Disneyland to End Current Annual Passport Program, Issue Refunds Due to Pandemic											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/california/california-heat-poor-planning-led-to-august-power-outages/2445210/">
#  									California Heat, Poor Planning Led to August Power Outages											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/investigations/series/no-mans-land/fighting-for-fatherhood-in-a-broken-system/2429602/">
#  									No Man's Land: Fighting for Fatherhood in a Broken System											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/digital-originals/2020-a-look-back-at-the-longest-12-months-ever/2433247/">
#  									2020: A Look Back at the Longest 12 Months Ever											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/race-for-a-vaccine/the-race-against-mutation-how-vaccines-will-keep-up-as-the-coronavirus-evolves/2420234/">
#  									The Race Against Mutation: How Vaccines Will Keep Up as the Coronavirus Evolves											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/digital-originals/making-virtual-school-a-slam-dunk-how-a-teen-run-nonprofit-is-helping-kids-bridge-the-digital-divide/2404691/">
#  									Making Virtual School a Slam Dunk: Teen-Run Nonprofit Helps Kids Bridge Digital Divide											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/bay-area-proud/12-year-old-raises-money-for-homeless-man-who-returned-grandmothers-lost-wallet/2431364/">
#  									12-Year-Old Raises Money for Homeless Man Who Returned Grandmother's Lost Wallet											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/bay-area-proud/drone-operator-rescues-woman-from-high-surf-captures-it-on-video/2426583/">
#  									Drone Operator Rescues Woman From High Surf, Captures it On Video											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/bay-area-proud/from-dramas-to-desks-south-bay-set-designer-uses-talents-to-help-remote-learners/2424446/">
#  									From Dramas to Desks: South Bay Set Designer Uses Talents to Help Remote Learners											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/bay-area-proud/5-year-olds-letter-to-city-about-lost-leg0-gets-kind-response/2418405/">
#  									5-Year-Old's Letter to City About Lost LEGO Gets Kind Response											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/sports/sharks-launch-audio-streaming-network-leave-kfox-radio-after-20-years/2445583/">
#  									Sharks Launch Audio Streaming Network, Leave KFOX Radio After 20 Years											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/sports/nbcsports/trent-williams-re-signs-with-49ers-on-massive-contract-pff-predicts/2445515/">
#  									Trent Williams Re-Signs With 49ers on Massive Contract, PFF Predicts											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/man-suffers-life-threatening-injuries-in-san-jose-shooting/2445191/">
#  									Man Dies Hours After Shooting in San Jose; No Arrests: SJPD											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/national-international/twitter-ceo-defends-trump-ban-cites-threats-to-physical-safety/2445497/">
#  									Twitter CEO Defends Trump Ban, Cites Threats to Physical Safety											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/sports/nbcsports/sharks-set-21-player-roster-ahead-of-2021-opener-vs-coyotes/2445344/">
#  									Sharks Set 21-Player Roster Ahead of 2021 Opener vs. Coyotes											</a>,
#  <a class="story-card__title-link" href="https://www.nbcbayarea.com/news/local/local-state-law-enforcement-monitor-far-right-groups-ahead-of-inauguration-day/2445434/">
#  									Local, State Law Enforcement Monitor Far-Right Groups Ahead of Inauguration Day											</a>]

# %%
# Create a list for dictionaries {"article_name": '', "link": ''}.  
all_articls = []

for ind in range(len(art_content)):
    title = art_content[ind].text.strip()
    link = art_content[ind].attrs['href']
    all_articls.append({"article_name": title, "link": link})
    
all_articls
# Out:
# [{'article_name': "Bay Area Seniors Hoping to Get COVID-19 Vaccine Feel ‘Discouraged' by Lack of Availability",
#   'link': 'https://www.nbcbayarea.com/coronavirus-2/bay-area-seniors-hoping-to-get-covid-19-vaccine-feel-discouraged-by-lack-of-availability/2445816/'},
#  {'article_name': 'Report: Energy Market Selloff Led to Blackouts in Record Heatwave',
#   'link': 'https://www.nbcbayarea.com/investigations/report-energy-market-selloff-led-to-blackouts-in-record-heatwave/2445860/'},
#  {'article_name': 'Current COVID-19 Vaccine Supply Not Enough to Vaccinate All Seniors Immediately',
#   'link': 'https://www.nbcbayarea.com/news/local/current-covid-19-vaccine-supply-not-enough-to-vaccinate-all-seniors-immediately/2445783/'},
#  {'article_name': 'SF Announces Over $62M in Relief Funds for Small Businesses as Pandemic Endures',
#   'link': 'https://www.nbcbayarea.com/news/local/san-francisco/sf-announces-over-62m-in-relief-funds-for-small-businesses-as-pandemic-endures/2444374/'},
#  {'article_name': 'BART to Hire 20 Trained Social Workers',
#   'link': 'https://www.nbcbayarea.com/news/local/bart-to-hire-20-trained-social-workers/2445364/'},
#  {'article_name': 'SF City Leaders Remain Hopeful as New COVID-19 Surge Post-Christmas Becomes Evident',
#   'link': 'https://www.nbcbayarea.com/news/local/san-francisco/sf-city-leaders-remain-hopeful-as-new-covid-19-surge-post-christmas-becomes-evident/2444096/'},
#  {'article_name': 'Property Owners Take a Hit as Pandemic-Induced Business Closures Continue',
#   'link': 'https://www.nbcbayarea.com/news/local/property-owners-take-a-hit-as-pandemic-induced-business-closures-continue/2445694/'},
#  {'article_name': 'COVID-19 Cases Soar at Santa Clara County Jail',
#   'link': 'https://www.nbcbayarea.com/news/local/south-bay/covid-19-cases-soar-at-santa-clara-county-jail/2445353/'},
#  {'article_name': '5-Number Powerball Ticket Worth $2.7M Sold in San Jose',
#   'link': 'https://www.nbcbayarea.com/news/local/south-bay/5-number-lotto-winner-in-san-jose/2445322/'},
#  {'article_name': 'Man Accused in Ghost Ship Fire That Killed 36 Expected to Plead Guilty',
#   'link': 'https://www.nbcbayarea.com/news/local/man-accused-in-ghost-ship-fire-that-killed-36-expected-to-plead-guilty/2445637/'},
#  {'article_name': '3.8 Magnitude Earthquake in Concord Felt Across Bay Area',
#   'link': 'https://www.nbcbayarea.com/news/local/3-8-magnitude-earthquake-strikes-in-concord-area/2445592/'},
#  {'article_name': 'Seniors 65 and Up Can Schedule COVID-19 Vaccine in Contra Costa County',
#   'link': 'https://www.nbcbayarea.com/news/local/race-for-a-vaccine/seniors-65-and-up-can-schedule-covid-19-vaccine-in-contra-costa-county/2445457/'},
#  {'article_name': 'Water Main Break in South San Francisco Leads to Extended Road Closure',
#   'link': 'https://www.nbcbayarea.com/news/local/peninsula/watermain-break-in-south-san-francisco-leads-to-extended-road-closure/2445410/'},
#  {'article_name': 'Authorities in San Mateo County Search for Missing 14-Year-Old',
#   'link': 'https://www.nbcbayarea.com/news/local/authorities-in-san-mateo-county-search-for-missing-14-year-old/2444975/'},
#  {'article_name': "San Mateo County's Community Wellness and Crisis Response Pilot Project Approved",
#   'link': 'https://www.nbcbayarea.com/news/local/peninsula/san-mateo-countys-community-wellness-and-crisis-response-pilot-project-approved/2444514/'},
#  {'article_name': 'Elephant Seals Take Over Beach in Marin County, Force Closure',
#   'link': 'https://www.nbcbayarea.com/news/local/elephant-seals-take-over-beach-in-marin-county-force-closure/2445635/'},
#  {'article_name': 'Santa Rosa Artist Honors Frontline Workers With Free Portraits',
#   'link': 'https://www.nbcbayarea.com/news/local/bay-area-proud/santa-rosa-artist-honors-front-line-workers-with-free-portraits/2444917/'},
#  {'article_name': 'Mass COVID-19 Vaccination Site Opens at Sonoma County Fairgrounds',
#   'link': 'https://www.nbcbayarea.com/news/local/mass-covid-19-vaccination-site-opens-at-sonoma-county-fairgrounds/2445114/'},
#  {'article_name': 'California Mobilizes National Guard Amid Concern Over Unrest',
#   'link': 'https://www.nbcbayarea.com/news/california/california-mobilizes-national-guard-amid-concern-over-unrest/2445755/'},
#  {'article_name': 'Disneyland to End Current Annual Passport Program, Issue Refunds Due to Pandemic',
#   'link': 'https://www.nbcbayarea.com/entertainment/entertainment-news/disneyland-to-end-current-annual-passport-program-issue-refunds-due-to-pandemic/2445698/'},
#  {'article_name': 'California Heat, Poor Planning Led to August Power Outages',
#   'link': 'https://www.nbcbayarea.com/news/california/california-heat-poor-planning-led-to-august-power-outages/2445210/'},
#  {'article_name': "No Man's Land: Fighting for Fatherhood in a Broken System",
#   'link': 'https://www.nbcbayarea.com/investigations/series/no-mans-land/fighting-for-fatherhood-in-a-broken-system/2429602/'},
#  {'article_name': '2020: A Look Back at the Longest 12 Months Ever',
#   'link': 'https://www.nbcbayarea.com/news/local/digital-originals/2020-a-look-back-at-the-longest-12-months-ever/2433247/'},
#  {'article_name': 'The Race Against Mutation: How Vaccines Will Keep Up as the Coronavirus Evolves',
#   'link': 'https://www.nbcbayarea.com/news/local/race-for-a-vaccine/the-race-against-mutation-how-vaccines-will-keep-up-as-the-coronavirus-evolves/2420234/'},
#  {'article_name': 'Making Virtual School a Slam Dunk: Teen-Run Nonprofit Helps Kids Bridge Digital Divide',
#   'link': 'https://www.nbcbayarea.com/news/local/digital-originals/making-virtual-school-a-slam-dunk-how-a-teen-run-nonprofit-is-helping-kids-bridge-the-digital-divide/2404691/'},
#  {'article_name': "12-Year-Old Raises Money for Homeless Man Who Returned Grandmother's Lost Wallet",
#   'link': 'https://www.nbcbayarea.com/news/local/bay-area-proud/12-year-old-raises-money-for-homeless-man-who-returned-grandmothers-lost-wallet/2431364/'},
#  {'article_name': 'Drone Operator Rescues Woman From High Surf, Captures it On Video',
#   'link': 'https://www.nbcbayarea.com/news/local/bay-area-proud/drone-operator-rescues-woman-from-high-surf-captures-it-on-video/2426583/'},
#  {'article_name': 'From Dramas to Desks: South Bay Set Designer Uses Talents to Help Remote Learners',
#   'link': 'https://www.nbcbayarea.com/news/local/bay-area-proud/from-dramas-to-desks-south-bay-set-designer-uses-talents-to-help-remote-learners/2424446/'},
#  {'article_name': "5-Year-Old's Letter to City About Lost LEGO Gets Kind Response",
#   'link': 'https://www.nbcbayarea.com/news/local/bay-area-proud/5-year-olds-letter-to-city-about-lost-leg0-gets-kind-response/2418405/'},
#  {'article_name': 'Sharks Launch Audio Streaming Network, Leave KFOX Radio After 20 Years',
#   'link': 'https://www.nbcbayarea.com/news/sports/sharks-launch-audio-streaming-network-leave-kfox-radio-after-20-years/2445583/'},
#  {'article_name': 'Trent Williams Re-Signs With 49ers on Massive Contract, PFF Predicts',
#   'link': 'https://www.nbcbayarea.com/news/sports/nbcsports/trent-williams-re-signs-with-49ers-on-massive-contract-pff-predicts/2445515/'},
#  {'article_name': 'Man Dies Hours After Shooting in San Jose; No Arrests: SJPD',
#   'link': 'https://www.nbcbayarea.com/news/local/man-suffers-life-threatening-injuries-in-san-jose-shooting/2445191/'},
#  {'article_name': 'Twitter CEO Defends Trump Ban, Cites Threats to Physical Safety',
#   'link': 'https://www.nbcbayarea.com/news/national-international/twitter-ceo-defends-trump-ban-cites-threats-to-physical-safety/2445497/'},
#  {'article_name': 'Sharks Set 21-Player Roster Ahead of 2021 Opener vs. Coyotes',
#   'link': 'https://www.nbcbayarea.com/news/sports/nbcsports/sharks-set-21-player-roster-ahead-of-2021-opener-vs-coyotes/2445344/'},
#  {'article_name': 'Local, State Law Enforcement Monitor Far-Right Groups Ahead of Inauguration Day',
#   'link': 'https://www.nbcbayarea.com/news/local/local-state-law-enforcement-monitor-far-right-groups-ahead-of-inauguration-day/2445434/'}]

# %%
# Take only first 3 stories
top_stories = all_articls[:3]
top_stories
# Out:
# [{'article_name': "Bay Area Seniors Hoping to Get COVID-19 Vaccine Feel ‘Discouraged' by Lack of Availability",
#   'link': 'https://www.nbcbayarea.com/coronavirus-2/bay-area-seniors-hoping-to-get-covid-19-vaccine-feel-discouraged-by-lack-of-availability/2445816/'},
#  {'article_name': 'Report: Energy Market Selloff Led to Blackouts in Record Heatwave',
#   'link': 'https://www.nbcbayarea.com/investigations/report-energy-market-selloff-led-to-blackouts-in-record-heatwave/2445860/'},
#  {'article_name': 'Current COVID-19 Vaccine Supply Not Enough to Vaccinate All Seniors Immediately',
#   'link': 'https://www.nbcbayarea.com/news/local/current-covid-19-vaccine-supply-not-enough-to-vaccinate-all-seniors-immediately/2445783/'}]

# %%
# extract content from each article, remove non letters sylabals and add content to dictionary

for story in top_stories:
    response = requests.get(story['link'])
    soup = BeautifulSoup(response.text, "html.parser")
    content = soup.find_all('p')
    
    story_content = []
    
    for ind in range(len(content)):
        temp = content[ind].text
        temp = re.sub("[^a-zA-Z]", " ", str(temp))
        story_content.append(temp)

    story.update({"content": story_content})
    
top_stories_pd = pd.DataFrame(top_stories)

# %% [markdown]
# ### Upload first 3 stories to sql

# %%
# Upload DF to postrge
top_stories_pd.to_sql('stories', conn, if_exists='append')

# %%
# extract words from content 

words_in_story = []

for i in range(3):
    query = f'SELECT * FROM stories WHERE index={i}'
    story = pd.read_sql(query, conn)
    for ind in range(len(story['content'])):
        words = story['content'][ind].split()
        
        for word in words:
            word = re.sub("[^a-zA-Z]", " ", word)
            word = word.strip()
            if len(word) > 0:                
                words_in_story.append({'story_index': i, 'word':  word.lower()})
        
words_in_story
# Out:
# [{'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'much'},
#  {'story_index': 0, 'word': 'fanfare'},
#  {'story_index': 0, 'word': 'governor'},
#  {'story_index': 0, 'word': 'gavin'},
#  {'story_index': 0, 'word': 'newsom'},
#  {'story_index': 0, 'word': 'announced'},
#  {'story_index': 0, 'word': 'wednesday'},
#  {'story_index': 0, 'word': 'that'},
#  {'story_index': 0, 'word': 'california'},
#  {'story_index': 0, 'word': 's'},
#  {'story_index': 0, 'word': 'covid'},
#  {'story_index': 0, 'word': 'vaccines'},
#  {'story_index': 0, 'word': 'would'},
#  {'story_index': 0, 'word': 'now'},
#  {'story_index': 0, 'word': 'be'},
#  {'story_index': 0, 'word': 'open'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'those'},
#  {'story_index': 0, 'word': 'and'},
#  {'story_index': 0, 'word': 'older'},
#  {'story_index': 0, 'word': 'but'},
#  {'story_index': 0, 'word': 'some'},
#  {'story_index': 0, 'word': 'say'},
#  {'story_index': 0, 'word': 'that'},
#  {'story_index': 0, 'word': 'when'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 'started'},
#  {'story_index': 0, 'word': 'trying'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'make'},
#  {'story_index': 0, 'word': 'an'},
#  {'story_index': 0, 'word': 'appointment'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 'got'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'runaround'},
#  {'story_index': 0, 'word': 'it'},
#  {'story_index': 0, 'word': 'means'},
#  {'story_index': 0, 'word': 'i'},
#  {'story_index': 0, 'word': 'll'},
#  {'story_index': 0, 'word': 'be'},
#  {'story_index': 0, 'word': 'able'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'see'},
#  {'story_index': 0, 'word': 'clients'},
#  {'story_index': 0, 'word': 'when'},
#  {'story_index': 0, 'word': 'friends'},
#  {'story_index': 0, 'word': 'get'},
#  {'story_index': 0, 'word': 'vaccinated'},
#  {'story_index': 0, 'word': 'i'},
#  {'story_index': 0, 'word': 'll'},
#  {'story_index': 0, 'word': 'be'},
#  {'story_index': 0, 'word': 'able'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'see'},
#  {'story_index': 0, 'word': 'them'},
#  {'story_index': 0, 'word': 'said'},
#  {'story_index': 0, 'word': 'barbara'},
#  {'story_index': 0, 'word': 'tetzlaff'},
#  {'story_index': 0, 'word': 'of'},
#  {'story_index': 0, 'word': 'san'},
#  {'story_index': 0, 'word': 'francisco'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'year'},
#  {'story_index': 0, 'word': 'old'},
#  {'story_index': 0, 'word': 'lawyer'},
#  {'story_index': 0, 'word': 'thought'},
#  {'story_index': 0, 'word': 'this'},
#  {'story_index': 0, 'word': 'would'},
#  {'story_index': 0, 'word': 'be'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'light'},
#  {'story_index': 0, 'word': 'at'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'end'},
#  {'story_index': 0, 'word': 'of'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'very'},
#  {'story_index': 0, 'word': 'long'},
#  {'story_index': 0, 'word': 'lockdown'},
#  {'story_index': 0, 'word': 'tunnel'},
#  {'story_index': 0, 'word': 'but'},
#  {'story_index': 0, 'word': 'just'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'day'},
#  {'story_index': 0, 'word': 'later'},
#  {'story_index': 0, 'word': 'after'},
#  {'story_index': 0, 'word': 'her'},
#  {'story_index': 0, 'word': 'doctor'},
#  {'story_index': 0, 'word': 'told'},
#  {'story_index': 0, 'word': 'her'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 'weren'},
#  {'story_index': 0, 'word': 't'},
#  {'story_index': 0, 'word': 'vaccinating'},
#  {'story_index': 0, 'word': 'and'},
#  {'story_index': 0, 'word': 'she'},
#  {'story_index': 0, 'word': 'couldn'},
#  {'story_index': 0, 'word': 't'},
#  {'story_index': 0, 'word': 'find'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'mass'},
#  {'story_index': 0, 'word': 'vaccination'},
#  {'story_index': 0, 'word': 'site'},
#  {'story_index': 0, 'word': 'that'},
#  {'story_index': 0, 'word': 'light'},
#  {'story_index': 0, 'word': 'is'},
#  {'story_index': 0, 'word': 'now'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'flicker'},
#  {'story_index': 0, 'word': 'i'},
#  {'story_index': 0, 'word': 'just'},
#  {'story_index': 0, 'word': 'keep'},
#  {'story_index': 0, 'word': 'running'},
#  {'story_index': 0, 'word': 'into'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'stone'},
#  {'story_index': 0, 'word': 'wall'},
#  {'story_index': 0, 'word': 'she'},
#  {'story_index': 0, 'word': 'said'},
#  {'story_index': 0, 'word': 'i'},
#  {'story_index': 0, 'word': 'understand'},
#  {'story_index': 0, 'word': 'that'},
#  {'story_index': 0, 'word': 'there'},
#  {'story_index': 0, 'word': 's'},
#  {'story_index': 0, 'word': 'not'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'lot'},
#  {'story_index': 0, 'word': 'of'},
#  {'story_index': 0, 'word': 'information'},
#  {'story_index': 0, 'word': 'or'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'lot'},
#  {'story_index': 0, 'word': 'of'},
#  {'story_index': 0, 'word': 'vaccines'},
#  {'story_index': 0, 'word': 'right'},
#  {'story_index': 0, 'word': 'now'},
#  {'story_index': 0, 'word': 'but'},
#  {'story_index': 0, 'word': 'there'},
#  {'story_index': 0, 'word': 'has'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'be'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'better'},
#  {'story_index': 0, 'word': 'way'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'do'},
#  {'story_index': 0, 'word': 'it'},
#  {'story_index': 0, 'word': 'other'},
#  {'story_index': 0, 'word': 'seniors'},
#  {'story_index': 0, 'word': 'say'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 've'},
#  {'story_index': 0, 'word': 'been'},
#  {'story_index': 0, 'word': 'directed'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'vaccine'},
#  {'story_index': 0, 'word': 'hotlines'},
#  {'story_index': 0, 'word': 'that'},
#  {'story_index': 0, 'word': 'lead'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'nowhere'},
#  {'story_index': 0, 'word': 'websites'},
#  {'story_index': 0, 'word': 'crashing'},
#  {'story_index': 0, 'word': 'or'},
#  {'story_index': 0, 'word': 'simply'},
#  {'story_index': 0, 'word': 'no'},
#  {'story_index': 0, 'word': 'information'},
#  {'story_index': 0, 'word': 'at'},
#  {'story_index': 0, 'word': 'all'},
#  {'story_index': 0, 'word': 'in'},
#  {'story_index': 0, 'word': 'an'},
#  {'story_index': 0, 'word': 'interview'},
#  {'story_index': 0, 'word': 'nbc'},
#  {'story_index': 0, 'word': 'news'},
#  {'story_index': 0, 'word': 'asked'},
#  {'story_index': 0, 'word': 'governor'},
#  {'story_index': 0, 'word': 'newsom'},
#  {'story_index': 0, 'word': 'how'},
#  {'story_index': 0, 'word': 'he'},
#  {'story_index': 0, 'word': 'd'},
#  {'story_index': 0, 'word': 'ensure'},
#  {'story_index': 0, 'word': 'long'},
#  {'story_index': 0, 'word': 'lines'},
#  {'story_index': 0, 'word': 'and'},
#  {'story_index': 0, 'word': 'logistical'},
#  {'story_index': 0, 'word': 'nightmares'},
#  {'story_index': 0, 'word': 'don'},
#  {'story_index': 0, 'word': 't'},
#  {'story_index': 0, 'word': 'happen'},
#  {'story_index': 0, 'word': 'in'},
#  {'story_index': 0, 'word': 'california'},
#  {'story_index': 0, 'word': 'you'},
#  {'story_index': 0, 'word': 'can'},
#  {'story_index': 0, 'word': 't'},
#  {'story_index': 0, 'word': 'ensure'},
#  {'story_index': 0, 'word': 'any'},
#  {'story_index': 0, 'word': 'of'},
#  {'story_index': 0, 'word': 'that'},
#  {'story_index': 0, 'word': 'it'},
#  {'story_index': 0, 'word': 's'},
#  {'story_index': 0, 'word': 'an'},
#  {'story_index': 0, 'word': 'unprecedented'},
#  {'story_index': 0, 'word': 'logistics'},
#  {'story_index': 0, 'word': 'operation'},
#  {'story_index': 0, 'word': 'said'},
#  {'story_index': 0, 'word': 'newsom'},
#  {'story_index': 0, 'word': 'or'},
#  {'story_index': 0, 'word': 'according'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'seniors'},
#  {'story_index': 0, 'word': 'just'},
#  {'story_index': 0, 'word': 'another'},
#  {'story_index': 0, 'word': 'way'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'pass'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'buck'},
#  {'story_index': 0, 'word': 'i'},
#  {'story_index': 0, 'word': 'think'},
#  {'story_index': 0, 'word': 'perhaps'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 'should'},
#  {'story_index': 0, 'word': 'have'},
#  {'story_index': 0, 'word': 'waited'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'make'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'announcement'},
#  {'story_index': 0, 'word': 'until'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 'had'},
#  {'story_index': 0, 'word': 'the'},
#  {'story_index': 0, 'word': 'facilities'},
#  {'story_index': 0, 'word': 'in'},
#  {'story_index': 0, 'word': 'place'},
#  {'story_index': 0, 'word': 'said'},
#  {'story_index': 0, 'word': 'tetzlaff'},
#  {'story_index': 0, 'word': 'it'},
#  {'story_index': 0, 'word': 'can'},
#  {'story_index': 0, 'word': 'be'},
#  {'story_index': 0, 'word': 'discouraging'},
#  {'story_index': 0, 'word': 'but'},
#  {'story_index': 0, 'word': 'i'},
#  {'story_index': 0, 'word': 'try'},
#  {'story_index': 0, 'word': 'not'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'let'},
#  {'story_index': 0, 'word': 'it'},
#  {'story_index': 0, 'word': 'get'},
#  {'story_index': 0, 'word': 'me'},
#  {'story_index': 0, 'word': 'because'},
#  {'story_index': 0, 'word': 'i'},
#  {'story_index': 0, 'word': 'm'},
#  {'story_index': 0, 'word': 'going'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'get'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'vaccine'},
#  {'story_index': 0, 'word': 'sutter'},
#  {'story_index': 0, 'word': 'health'},
#  {'story_index': 0, 'word': 'said'},
#  {'story_index': 0, 'word': 'several'},
#  {'story_index': 0, 'word': 'people'},
#  {'story_index': 0, 'word': 'who'},
#  {'story_index': 0, 'word': 'are'},
#  {'story_index': 0, 'word': 'and'},
#  {'story_index': 0, 'word': 'older'},
#  {'story_index': 0, 'word': 'walked'},
#  {'story_index': 0, 'word': 'into'},
#  {'story_index': 0, 'word': 'a'},
#  {'story_index': 0, 'word': 'medical'},
#  {'story_index': 0, 'word': 'office'},
#  {'story_index': 0, 'word': 'on'},
#  {'story_index': 0, 'word': 'van'},
#  {'story_index': 0, 'word': 'ness'},
#  {'story_index': 0, 'word': 'and'},
#  {'story_index': 0, 'word': 'received'},
#  {'story_index': 0, 'word': 'covid'},
#  {'story_index': 0, 'word': 'vaccines'},
#  {'story_index': 0, 'word': 'nbc'},
#  {'story_index': 0, 'word': 'bay'},
#  {'story_index': 0, 'word': 'area'},
#  {'story_index': 0, 'word': 'reached'},
#  {'story_index': 0, 'word': 'out'},
#  {'story_index': 0, 'word': 'to'},
#  {'story_index': 0, 'word': 'several'},
#  {'story_index': 0, 'word': 'other'},
#  {'story_index': 0, 'word': 'health'},
#  {'story_index': 0, 'word': 'care'},
#  {'story_index': 0, 'word': 'providers'},
#  {'story_index': 0, 'word': 'and'},
#  {'story_index': 0, 'word': 'many'},
#  {'story_index': 0, 'word': 'say'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 'will'},
#  {'story_index': 0, 'word': 'notify'},
#  {'story_index': 0, 'word': 'their'},
#  {'story_index': 0, 'word': 'patients'},
#  {'story_index': 0, 'word': 'when'},
#  {'story_index': 0, 'word': 'they'},
#  {'story_index': 0, 'word': 're'},
#  {'story_index': 0, 'word': 'eligible'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'final'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'on'},
#  {'story_index': 1, 'word': 'what'},
#  {'story_index': 1, 'word': 'triggered'},
#  {'story_index': 1, 'word': 'last'},
#  {'story_index': 1, 'word': 'year'},
#  {'story_index': 1, 'word': 's'},
#  {'story_index': 1, 'word': 'massive'},
#  {'story_index': 1, 'word': 'power'},
#  {'story_index': 1, 'word': 'outages'},
#  {'story_index': 1, 'word': 'acknowledges'},
#  {'story_index': 1, 'word': 'that'},
#  {'story_index': 1, 'word': 'state'},
#  {'story_index': 1, 'word': 'energy'},
#  {'story_index': 1, 'word': 'market'},
#  {'story_index': 1, 'word': 'practices'},
#  {'story_index': 1, 'word': 'allowed'},
#  {'story_index': 1, 'word': 'thousands'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'megawatts'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'desperately'},
#  {'story_index': 1, 'word': 'needed'},
#  {'story_index': 1, 'word': 'power'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'be'},
#  {'story_index': 1, 'word': 'exported'},
#  {'story_index': 1, 'word': 'out'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'state'},
#  {'story_index': 1, 'word': 'at'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'peak'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'mid'},
#  {'story_index': 1, 'word': 'august'},
#  {'story_index': 1, 'word': 'heatwave'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'examining'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'root'},
#  {'story_index': 1, 'word': 'causes'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'outages'},
#  {'story_index': 1, 'word': 'on'},
#  {'story_index': 1, 'word': 'aug'},
#  {'story_index': 1, 'word': 'and'},
#  {'story_index': 1, 'word': 'when'},
#  {'story_index': 1, 'word': 'california'},
#  {'story_index': 1, 'word': 'endured'},
#  {'story_index': 1, 'word': 'record'},
#  {'story_index': 1, 'word': 'temperatures'},
#  {'story_index': 1, 'word': 'that'},
#  {'story_index': 1, 'word': 'left'},
#  {'story_index': 1, 'word': 'more'},
#  {'story_index': 1, 'word': 'than'},
#  {'story_index': 1, 'word': 'people'},
#  {'story_index': 1, 'word': 'without'},
#  {'story_index': 1, 'word': 'power'},
#  {'story_index': 1, 'word': 'was'},
#  {'story_index': 1, 'word': 'generated'},
#  {'story_index': 1, 'word': 'at'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'demand'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'gov'},
#  {'story_index': 1, 'word': 'gavin'},
#  {'story_index': 1, 'word': 'newsom'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'embarrassed'},
#  {'story_index': 1, 'word': 'governor'},
#  {'story_index': 1, 'word': 'called'},
#  {'story_index': 1, 'word': 'out'},
#  {'story_index': 1, 'word': 'california'},
#  {'story_index': 1, 'word': 's'},
#  {'story_index': 1, 'word': 'independent'},
#  {'story_index': 1, 'word': 'system'},
#  {'story_index': 1, 'word': 'operator'},
#  {'story_index': 1, 'word': 'and'},
#  {'story_index': 1, 'word': 'state'},
#  {'story_index': 1, 'word': 'energy'},
#  {'story_index': 1, 'word': 'and'},
#  {'story_index': 1, 'word': 'utility'},
#  {'story_index': 1, 'word': 'regulators'},
#  {'story_index': 1, 'word': 'demanding'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'know'},
#  {'story_index': 1, 'word': 'what'},
#  {'story_index': 1, 'word': 'went'},
#  {'story_index': 1, 'word': 'wrong'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'final'},
#  {'story_index': 1, 'word': 'page'},
#  {'story_index': 1, 'word': 'joint'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'released'},
#  {'story_index': 1, 'word': 'wednesday'},
#  {'story_index': 1, 'word': 'points'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'everything'},
#  {'story_index': 1, 'word': 'from'},
#  {'story_index': 1, 'word': 'climate'},
#  {'story_index': 1, 'word': 'change'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'poor'},
#  {'story_index': 1, 'word': 'planning'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'smoke'},
#  {'story_index': 1, 'word': 'from'},
#  {'story_index': 1, 'word': 'wildfires'},
#  {'story_index': 1, 'word': 'hindering'},
#  {'story_index': 1, 'word': 'rooftop'},
#  {'story_index': 1, 'word': 'solar'},
#  {'story_index': 1, 'word': 'production'},
#  {'story_index': 1, 'word': 'as'},
#  {'story_index': 1, 'word': 'factors'},
#  {'story_index': 1, 'word': 'but'},
#  {'story_index': 1, 'word': 'critics'},
#  {'story_index': 1, 'word': 'like'},
#  {'story_index': 1, 'word': 'former'},
#  {'story_index': 1, 'word': 'cpuc'},
#  {'story_index': 1, 'word': 'president'},
#  {'story_index': 1, 'word': 'loretta'},
#  {'story_index': 1, 'word': 'lynch'},
#  {'story_index': 1, 'word': 'were'},
#  {'story_index': 1, 'word': 'not'},
#  {'story_index': 1, 'word': 'satisfied'},
#  {'story_index': 1, 'word': 'by'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'findings'},
#  {'story_index': 1, 'word': 'we'},
#  {'story_index': 1, 'word': 've'},
#  {'story_index': 1, 'word': 'got'},
#  {'story_index': 1, 'word': 'a'},
#  {'story_index': 1, 'word': 'lot'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'unanswered'},
#  {'story_index': 1, 'word': 'questions'},
#  {'story_index': 1, 'word': 'with'},
#  {'story_index': 1, 'word': 'this'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'said'},
#  {'story_index': 1, 'word': 'lynch'},
#  {'story_index': 1, 'word': 'who'},
#  {'story_index': 1, 'word': 'said'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'does'},
#  {'story_index': 1, 'word': 'not'},
#  {'story_index': 1, 'word': 'go'},
#  {'story_index': 1, 'word': 'far'},
#  {'story_index': 1, 'word': 'enough'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'explain'},
#  {'story_index': 1, 'word': 'what'},
#  {'story_index': 1, 'word': 'led'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'meltdown'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'does'},
#  {'story_index': 1, 'word': 'cite'},
#  {'story_index': 1, 'word': 'energy'},
#  {'story_index': 1, 'word': 'market'},
#  {'story_index': 1, 'word': 'practices'},
#  {'story_index': 1, 'word': 'as'},
#  {'story_index': 1, 'word': 'having'},
#  {'story_index': 1, 'word': 'contributed'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'inability'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'obtain'},
#  {'story_index': 1, 'word': 'or'},
#  {'story_index': 1, 'word': 'prioritize'},
#  {'story_index': 1, 'word': 'energy'},
#  {'story_index': 1, 'word': 'that'},
#  {'story_index': 1, 'word': 'could'},
#  {'story_index': 1, 'word': 'have'},
#  {'story_index': 1, 'word': 'otherwise'},
#  {'story_index': 1, 'word': 'relieved'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'strained'},
#  {'story_index': 1, 'word': 'conditions'},
#  {'story_index': 1, 'word': 'on'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'grid'},
#  {'story_index': 1, 'word': 'but'},
#  {'story_index': 1, 'word': 'lynch'},
#  {'story_index': 1, 'word': 'says'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'doesn'},
#  {'story_index': 1, 'word': 't'},
#  {'story_index': 1, 'word': 'detail'},
#  {'story_index': 1, 'word': 'what'},
#  {'story_index': 1, 'word': 'led'},
#  {'story_index': 1, 'word': 'grid'},
#  {'story_index': 1, 'word': 'managers'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'disregard'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'weather'},
#  {'story_index': 1, 'word': 'based'},
#  {'story_index': 1, 'word': 'market'},
#  {'story_index': 1, 'word': 'forecast'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'high'},
#  {'story_index': 1, 'word': 'demand'},
#  {'story_index': 1, 'word': 'during'},
#  {'story_index': 1, 'word': 'an'},
#  {'story_index': 1, 'word': 'extreme'},
#  {'story_index': 1, 'word': 'heatwave'},
#  {'story_index': 1, 'word': 'and'},
#  {'story_index': 1, 'word': 'why'},
#  {'story_index': 1, 'word': 'they'},
#  {'story_index': 1, 'word': 'allowed'},
#  {'story_index': 1, 'word': 'a'},
#  {'story_index': 1, 'word': 'large'},
#  {'story_index': 1, 'word': 'chunk'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'state'},
#  {'story_index': 1, 'word': 's'},
#  {'story_index': 1, 'word': 'reserves'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'be'},
#  {'story_index': 1, 'word': 'sold'},
#  {'story_index': 1, 'word': 'off'},
#  {'story_index': 1, 'word': 'in'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'day'},
#  {'story_index': 1, 'word': 'ahead'},
#  {'story_index': 1, 'word': 'energy'},
#  {'story_index': 1, 'word': 'market'},
#  {'story_index': 1, 'word': 'she'},
#  {'story_index': 1, 'word': 'says'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'crisis'},
#  {'story_index': 1, 'word': 'could'},
#  {'story_index': 1, 'word': 'have'},
#  {'story_index': 1, 'word': 'been'},
#  {'story_index': 1, 'word': 'averted'},
#  {'story_index': 1, 'word': 'had'},
#  {'story_index': 1, 'word': 'grid'},
#  {'story_index': 1, 'word': 'managers'},
#  {'story_index': 1, 'word': 'intervened'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'stop'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'exports'},
#  {'story_index': 1, 'word': 'they'},
#  {'story_index': 1, 'word': 'allowed'},
#  {'story_index': 1, 'word': 'megawatts'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'leave'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'state'},
#  {'story_index': 1, 'word': 'on'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'hottest'},
#  {'story_index': 1, 'word': 'day'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'century'},
#  {'story_index': 1, 'word': 'she'},
#  {'story_index': 1, 'word': 'said'},
#  {'story_index': 1, 'word': 'in'},
#  {'story_index': 1, 'word': 'a'},
#  {'story_index': 1, 'word': 'statement'},
#  {'story_index': 1, 'word': 'accompanying'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'release'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'report'},
#  {'story_index': 1, 'word': 'ca'},
#  {'story_index': 1, 'word': 'iso'},
#  {'story_index': 1, 'word': 's'},
#  {'story_index': 1, 'word': 'ceo'},
#  {'story_index': 1, 'word': 'elliot'},
#  {'story_index': 1, 'word': 'mainzer'},
#  {'story_index': 1, 'word': 'pledged'},
#  {'story_index': 1, 'word': 'that'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'important'},
#  {'story_index': 1, 'word': 'insights'},
#  {'story_index': 1, 'word': 'and'},
#  {'story_index': 1, 'word': 'lessons'},
#  {'story_index': 1, 'word': 'learned'},
#  {'story_index': 1, 'word': 'from'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'analysis'},
#  {'story_index': 1, 'word': 'would'},
#  {'story_index': 1, 'word': 'guide'},
#  {'story_index': 1, 'word': 'any'},
#  {'story_index': 1, 'word': 'reforms'},
#  {'story_index': 1, 'word': 'designed'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'assure'},
#  {'story_index': 1, 'word': 'a'},
#  {'story_index': 1, 'word': 'modernized'},
#  {'story_index': 1, 'word': 'and'},
#  {'story_index': 1, 'word': 'well'},
#  {'story_index': 1, 'word': 'integrated'},
#  {'story_index': 1, 'word': 'energy'},
#  {'story_index': 1, 'word': 'grid'},
#  {'story_index': 1, 'word': 'but'},
#  {'story_index': 1, 'word': 'lynch'},
#  {'story_index': 1, 'word': 'maintains'},
#  {'story_index': 1, 'word': 'that'},
#  {'story_index': 1, 'word': 'until'},
#  {'story_index': 1, 'word': 'regulators'},
#  {'story_index': 1, 'word': 'actually'},
#  {'story_index': 1, 'word': 'know'},
#  {'story_index': 1, 'word': 'what'},
#  {'story_index': 1, 'word': 'made'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'market'},
#  {'story_index': 1, 'word': 'system'},
#  {'story_index': 1, 'word': 'so'},
#  {'story_index': 1, 'word': 'vulnerable'},
#  {'story_index': 1, 'word': 'in'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'first'},
#  {'story_index': 1, 'word': 'place'},
#  {'story_index': 1, 'word': 'and'},
#  {'story_index': 1, 'word': 'act'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'address'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'underlying'},
#  {'story_index': 1, 'word': 'issue'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'system'},
#  {'story_index': 1, 'word': 'could'},
#  {'story_index': 1, 'word': 'still'},
#  {'story_index': 1, 'word': 'be'},
#  {'story_index': 1, 'word': 'prone'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'another'},
#  {'story_index': 1, 'word': 'meltdown'},
#  {'story_index': 1, 'word': 'frankly'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'government'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'california'},
#  {'story_index': 1, 'word': 'needs'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'get'},
#  {'story_index': 1, 'word': 'to'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'bottom'},
#  {'story_index': 1, 'word': 'of'},
#  {'story_index': 1, 'word': 'this'},
#  {'story_index': 1, 'word': 'she'},
#  {'story_index': 1, 'word': 'said'},
#  {'story_index': 1, 'word': 'because'},
#  {'story_index': 1, 'word': 'californians'},
#  {'story_index': 1, 'word': 'are'},
#  {'story_index': 1, 'word': 'not'},
#  {'story_index': 1, 'word': 'safe'},
#  {'story_index': 1, 'word': 'from'},
#  {'story_index': 1, 'word': 'blackouts'},
#  {'story_index': 1, 'word': 'until'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'market'},
#  {'story_index': 1, 'word': 'rules'},
#  {'story_index': 1, 'word': 'that'},
#  {'story_index': 1, 'word': 'allowed'},
#  {'story_index': 1, 'word': 'the'},
#  {'story_index': 1, 'word': 'black'},
#  {'story_index': 1, 'word': 'outs'},
#  {'story_index': 1, 'word': 'get'},
#  {'story_index': 1, 'word': 'fixed'},
#  {'story_index': 2, 'word': 'california'},
#  {'story_index': 2, 'word': 'gov'},
#  {'story_index': 2, 'word': 'gavin'},
#  {'story_index': 2, 'word': 'newsom'},
#  {'story_index': 2, 'word': 'on'},
#  {'story_index': 2, 'word': 'wednesday'},
#  {'story_index': 2, 'word': 'announced'},
#  {'story_index': 2, 'word': 'that'},
#  {'story_index': 2, 'word': 'anyone'},
#  {'story_index': 2, 'word': 'years'},
#  {'story_index': 2, 'word': 'of'},
#  {'story_index': 2, 'word': 'age'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'older'},
#  {'story_index': 2, 'word': 'qualified'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'get'},
#  {'story_index': 2, 'word': 'a'},
#  {'story_index': 2, 'word': 'covid'},
#  {'story_index': 2, 'word': 'vaccine'},
#  {'story_index': 2, 'word': 'immediately'},
#  {'story_index': 2, 'word': 'but'},
#  {'story_index': 2, 'word': 'actually'},
#  {'story_index': 2, 'word': 'vaccinating'},
#  {'story_index': 2, 'word': 'those'},
#  {'story_index': 2, 'word': 'now'},
#  {'story_index': 2, 'word': 'eligible'},
#  {'story_index': 2, 'word': 'isn'},
#  {'story_index': 2, 'word': 't'},
#  {'story_index': 2, 'word': 'necessarily'},
#  {'story_index': 2, 'word': 'happening'},
#  {'story_index': 2, 'word': 'right'},
#  {'story_index': 2, 'word': 'away'},
#  {'story_index': 2, 'word': 'vaccine'},
#  {'story_index': 2, 'word': 'providers'},
#  {'story_index': 2, 'word': 'say'},
#  {'story_index': 2, 'word': 'they'},
#  {'story_index': 2, 'word': 're'},
#  {'story_index': 2, 'word': 'simply'},
#  {'story_index': 2, 'word': 'not'},
#  {'story_index': 2, 'word': 'ready'},
#  {'story_index': 2, 'word': 'for'},
#  {'story_index': 2, 'word': 'a'},
#  {'story_index': 2, 'word': 'rush'},
#  {'story_index': 2, 'word': 'of'},
#  {'story_index': 2, 'word': 'new'},
#  {'story_index': 2, 'word': 'people'},
#  {'story_index': 2, 'word': 'looking'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'get'},
#  {'story_index': 2, 'word': 'vaccinated'},
#  {'story_index': 2, 'word': 'at'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'cypress'},
#  {'story_index': 2, 'word': 'senior'},
#  {'story_index': 2, 'word': 'center'},
#  {'story_index': 2, 'word': 'in'},
#  {'story_index': 2, 'word': 'san'},
#  {'story_index': 2, 'word': 'jose'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'announcement'},
#  {'story_index': 2, 'word': 'that'},
#  {'story_index': 2, 'word': 'those'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'older'},
#  {'story_index': 2, 'word': 'were'},
#  {'story_index': 2, 'word': 'now'},
#  {'story_index': 2, 'word': 'eligible'},
#  {'story_index': 2, 'word': 'for'},
#  {'story_index': 2, 'word': 'vaccinations'},
#  {'story_index': 2, 'word': 'triggered'},
#  {'story_index': 2, 'word': 'a'},
#  {'story_index': 2, 'word': 'lot'},
#  {'story_index': 2, 'word': 'of'},
#  {'story_index': 2, 'word': 'excitement'},
#  {'story_index': 2, 'word': 'but'},
#  {'story_index': 2, 'word': 'as'},
#  {'story_index': 2, 'word': 'many'},
#  {'story_index': 2, 'word': 'seniors'},
#  {'story_index': 2, 'word': 'have'},
#  {'story_index': 2, 'word': 'been'},
#  {'story_index': 2, 'word': 'finding'},
#  {'story_index': 2, 'word': 'out'},
#  {'story_index': 2, 'word': 'being'},
#  {'story_index': 2, 'word': 'eligible'},
#  {'story_index': 2, 'word': 'doesn'},
#  {'story_index': 2, 'word': 't'},
#  {'story_index': 2, 'word': 'mean'},
#  {'story_index': 2, 'word': 'there'},
#  {'story_index': 2, 'word': 'are'},
#  {'story_index': 2, 'word': 'enough'},
#  {'story_index': 2, 'word': 'shots'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'go'},
#  {'story_index': 2, 'word': 'around'},
#  {'story_index': 2, 'word': 'kuiwon'},
#  {'story_index': 2, 'word': 'song'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'when'},
#  {'story_index': 2, 'word': 'she'},
#  {'story_index': 2, 'word': 'tried'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'make'},
#  {'story_index': 2, 'word': 'a'},
#  {'story_index': 2, 'word': 'vaccination'},
#  {'story_index': 2, 'word': 'appointment'},
#  {'story_index': 2, 'word': 'all'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'websites'},
#  {'story_index': 2, 'word': 'crashed'},
#  {'story_index': 2, 'word': 'they'},
#  {'story_index': 2, 'word': 'sent'},
#  {'story_index': 2, 'word': 'me'},
#  {'story_index': 2, 'word': 'all'},
#  {'story_index': 2, 'word': 'these'},
#  {'story_index': 2, 'word': 'different'},
#  {'story_index': 2, 'word': 'links'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'i'},
#  {'story_index': 2, 'word': 'went'},
#  {'story_index': 2, 'word': 'on'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'every'},
#  {'story_index': 2, 'word': 'website'},
#  {'story_index': 2, 'word': 'is'},
#  {'story_index': 2, 'word': 'crashed'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'you'},
#  {'story_index': 2, 'word': 'can'},
#  {'story_index': 2, 'word': 't'},
#  {'story_index': 2, 'word': 'do'},
#  {'story_index': 2, 'word': 'it'},
#  {'story_index': 2, 'word': 'she'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'so'},
#  {'story_index': 2, 'word': 'then'},
#  {'story_index': 2, 'word': 'i'},
#  {'story_index': 2, 'word': 'was'},
#  {'story_index': 2, 'word': 'calling'},
#  {'story_index': 2, 'word': 'my'},
#  {'story_index': 2, 'word': 'stanford'},
#  {'story_index': 2, 'word': 'health'},
#  {'story_index': 2, 'word': 'care'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'then'},
#  {'story_index': 2, 'word': 'they'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'oh'},
#  {'story_index': 2, 'word': 'i'},
#  {'story_index': 2, 'word': 'm'},
#  {'story_index': 2, 'word': 'going'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'send'},
#  {'story_index': 2, 'word': 'you'},
#  {'story_index': 2, 'word': 'this'},
#  {'story_index': 2, 'word': 'message'},
#  {'story_index': 2, 'word': 'so'},
#  {'story_index': 2, 'word': 'i'},
#  {'story_index': 2, 'word': 'opened'},
#  {'story_index': 2, 'word': 'it'},
#  {'story_index': 2, 'word': 'yesterday'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'it'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'wait'},
#  {'story_index': 2, 'word': 'until'},
#  {'story_index': 2, 'word': 'we'},
#  {'story_index': 2, 'word': 'contact'},
#  {'story_index': 2, 'word': 'you'},
#  {'story_index': 2, 'word': 'getting'},
#  {'story_index': 2, 'word': 'an'},
#  {'story_index': 2, 'word': 'appointment'},
#  {'story_index': 2, 'word': 'for'},
#  {'story_index': 2, 'word': 'her'},
#  {'story_index': 2, 'word': 'year'},
#  {'story_index': 2, 'word': 'old'},
#  {'story_index': 2, 'word': 'mom'},
#  {'story_index': 2, 'word': 'wasn'},
#  {'story_index': 2, 'word': 't'},
#  {'story_index': 2, 'word': 'any'},
#  {'story_index': 2, 'word': 'easier'},
#  {'story_index': 2, 'word': 'we'},
#  {'story_index': 2, 'word': 'actually'},
#  {'story_index': 2, 'word': 'contacted'},
#  {'story_index': 2, 'word': 'her'},
#  {'story_index': 2, 'word': 'primary'},
#  {'story_index': 2, 'word': 'care'},
#  {'story_index': 2, 'word': 'physician'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'they'},
#  {'story_index': 2, 'word': 're'},
#  {'story_index': 2, 'word': 'waiting'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'get'},
#  {'story_index': 2, 'word': 'a'},
#  {'story_index': 2, 'word': 'load'},
#  {'story_index': 2, 'word': 'of'},
#  {'story_index': 2, 'word': 'vaccine'},
#  {'story_index': 2, 'word': 'so'},
#  {'story_index': 2, 'word': 'they'},
#  {'story_index': 2, 'word': 'can'},
#  {'story_index': 2, 'word': 'vaccinate'},
#  {'story_index': 2, 'word': 'people'},
#  {'story_index': 2, 'word': 'their'},
#  {'story_index': 2, 'word': 'patients'},
#  {'story_index': 2, 'word': 'song'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'santa'},
#  {'story_index': 2, 'word': 'clara'},
#  {'story_index': 2, 'word': 'county'},
#  {'story_index': 2, 'word': 'public'},
#  {'story_index': 2, 'word': 'health'},
#  {'story_index': 2, 'word': 'department'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'that'},
#  {'story_index': 2, 'word': 's'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'problem'},
#  {'story_index': 2, 'word': 'pointing'},
#  {'story_index': 2, 'word': 'out'},
#  {'story_index': 2, 'word': 'it'},
#  {'story_index': 2, 'word': 'doesn'},
#  {'story_index': 2, 'word': 't'},
#  {'story_index': 2, 'word': 'have'},
#  {'story_index': 2, 'word': 'enough'},
#  {'story_index': 2, 'word': 'doses'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'cover'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'frontline'},
#  {'story_index': 2, 'word': 'health'},
#  {'story_index': 2, 'word': 'workers'},
#  {'story_index': 2, 'word': 'much'},
#  {'story_index': 2, 'word': 'less'},
#  {'story_index': 2, 'word': 'another'},
#  {'story_index': 2, 'word': 'people'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'older'},
#  {'story_index': 2, 'word': 'sarah'},
#  {'story_index': 2, 'word': 'sherwood'},
#  {'story_index': 2, 'word': 'who'},
#  {'story_index': 2, 'word': 'represents'},
#  {'story_index': 2, 'word': 'good'},
#  {'story_index': 2, 'word': 'samaritan'},
#  {'story_index': 2, 'word': 'hospital'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'regional'},
#  {'story_index': 2, 'word': 'medical'},
#  {'story_index': 2, 'word': 'center'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'they'},
#  {'story_index': 2, 'word': 'want'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'vaccinate'},
#  {'story_index': 2, 'word': 'as'},
#  {'story_index': 2, 'word': 'many'},
#  {'story_index': 2, 'word': 'people'},
#  {'story_index': 2, 'word': 'as'},
#  {'story_index': 2, 'word': 'possible'},
#  {'story_index': 2, 'word': 'and'},
#  {'story_index': 2, 'word': 'are'},
#  {'story_index': 2, 'word': 'bracing'},
#  {'story_index': 2, 'word': 'for'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'rush'},
#  {'story_index': 2, 'word': 'it'},
#  {'story_index': 2, 'word': 's'},
#  {'story_index': 2, 'word': 'just'},
#  {'story_index': 2, 'word': 'day'},
#  {'story_index': 2, 'word': 'after'},
#  {'story_index': 2, 'word': 'day'},
#  {'story_index': 2, 'word': 'of'},
#  {'story_index': 2, 'word': 'very'},
#  {'story_index': 2, 'word': 'long'},
#  {'story_index': 2, 'word': 'hours'},
#  {'story_index': 2, 'word': 'so'},
#  {'story_index': 2, 'word': 'that'},
#  {'story_index': 2, 'word': 'we'},
#  {'story_index': 2, 'word': 'can'},
#  {'story_index': 2, 'word': 'obey'},
#  {'story_index': 2, 'word': 'those'},
#  {'story_index': 2, 'word': 'orders'},
#  {'story_index': 2, 'word': 'that'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'governor'},
#  {'story_index': 2, 'word': 'has'},
#  {'story_index': 2, 'word': 'given'},
#  {'story_index': 2, 'word': 'she'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'for'},
#  {'story_index': 2, 'word': 'just'},
#  {'story_index': 2, 'word': 'about'},
#  {'story_index': 2, 'word': 'every'},
#  {'story_index': 2, 'word': 'agency'},
#  {'story_index': 2, 'word': 'involved'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'key'},
#  {'story_index': 2, 'word': 'to'},
#  {'story_index': 2, 'word': 'meeting'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'demand'},
#  {'story_index': 2, 'word': 'is'},
#  {'story_index': 2, 'word': 'getting'},
#  {'story_index': 2, 'word': 'more'},
#  {'story_index': 2, 'word': 'vaccine'},
#  {'story_index': 2, 'word': 'supply'},
#  {'story_index': 2, 'word': 'at'},
#  {'story_index': 2, 'word': 'this'},
#  {'story_index': 2, 'word': 'point'},
#  {'story_index': 2, 'word': 'the'},
#  {'story_index': 2, 'word': 'county'},
#  {'story_index': 2, 'word': 'said'},
#  {'story_index': 2, 'word': 'it'},
#  ...]

# %%
# create DF from lists of dictionary with words from article
words_in_story_df = pd.DataFrame(words_in_story)

# %%
# Count unique words per article
story_df = pd.DataFrame(columns=['word', 'appearence', 'art_index'])
for i in range(3):
    story = words_in_story_df[words_in_story_df['story_index'] == i]
    temp_story_df = pd.DataFrame(story['word'].value_counts())
    temp_story_df['art_index'] = i
    temp_story_df.reset_index(inplace=True)
    temp_story_df.rename(columns={'index': 'word', 'word': 'appearence'}, inplace=True)
    story_df = story_df.append(temp_story_df)
story_df.tail(30)
# Out:
#            word appearence art_index
# 160         say          1         2
# 161     meeting          1         2
# 162          go          1         2
# 163    stanford          1         2
# 164      public          1         2
# 165         how          1         2
# 166       hours          1         2
# 167      kuiwon          1         2
# 168  represents          1         2
# 169     message          1         2
# 170   different          1         2
# 171    pointing          1         2
# 172        away          1         2
# 173    possible          1         2
# 174        wait          1         2
# 175        mean          1         2
# 176     contact          1         2
# 177        load          1         2
# 178       cover          1         2
# 179     looking          1         2
# 180     medical          1         2
# 181       these          1         2
# 182          or          1         2
# 183      around          1         2
# 184       after          1         2
# 185       right          1         2
# 186         gov          1         2
# 187          oh          1         2
# 188     bracing          1         2
# 189       ready          1         2

# %%
story_df.reset_index(inplace=True)

# %% [markdown]
# ### Add category for  words

# %%
story_df['category'] = ''

for ind in range(len(story_df['word'])):
    if story_df.iloc[ind]['word'] in articles:
        story_df.loc[ind, 'category'] = 'article'        
    
    if story_df.iloc[ind]['word'] in weekdays:
        story_df.loc[ind, 'category'] = 'weekday'
        
    if story_df.iloc[ind]['word'] in months:
        story_df.loc[ind, 'category'] = 'month'
               
    if story_df.iloc[ind]['word'] in prepositions:
        story_df.loc[ind, 'category'] = 'preposition'
        
    if story_df.iloc[ind]['word'] in pronouns:
        story_df.loc[ind, 'category'] = 'pronoun'
        
    if story_df.iloc[ind]['word'] in conjuctions:
        story_df.loc[ind, 'category'] = 'conjunction'
        

story_df.drop(['index'], axis=1, inplace=True)
story_df.head()
# Out:
#    word appearence art_index     category
# 0    to         15         0  preposition
# 1     a         10         0      article
# 2   the          8         0      article
# 3  they          8         0      pronoun
# 4     i          7         0      pronoun

# %% [markdown]
# ### Upload result to postgres

# %%
story_df.to_sql('story_vocabulary', conn, if_exists='append')

# %%
words_for_translation = pd.read_sql("SELECT * FROM story_vocabulary \
                                    WHERE category NOT IN ('pronoun', 'preposition', 'article') AND art_index=1", conn)

words_for_translation.head(30)
# Out:
#     index        word  appearence  art_index     category
# 0     181      report           8          1
# 1     182         and           7          1  conjunction
# 2     183      market           6          1
# 3     184      energy           6          1
# 4     186        what           5          1  conjunction
# 5     187       state           5          1
# 6     189       lynch           4          1
# 7     191     allowed           4          1
# 8     192        said           4          1
# 9     193        grid           4          1
# 10    195           s           4          1
# 11    197          be           3          1
# 12    198         but           3          1  conjunction
# 13    199       power           3          1
# 14    200       could           3          1
# 15    202      system           3          1
# 16    203  california           3          1
# 17    204         not           3          1
# 18    205       final           2          1
# 19    206   practices           2          1
# 20    207        does           2          1
# 21    208  regulators           2          1
# 22    209        says           2          1
# 23    211    heatwave           2          1
# 24    212         day           2          1
# 25    214    meltdown           2          1
# 26    217         led           2          1
# 27    219        have           2          1
# 28    220        know           2          1
# 29    221   megawatts           2          1
